# %%
# %tensorflow_version 1.x
import tensorflow as tf
import numpy as np
print(tf.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
# ML-> L1/L2 regulartion -> ridge/lasso
# ML ensemble (DT, RF, DJ..)-> Boosting/Bagging  
# Game theory-> adversary-> award and penalize the network  


# Dropout Layer-> Lesser you know, the more you know
# Data Augmentation-> twist the data by math/stat/SME based transformation 
# Hyperparameter tuning-> best set of HPs to use? 
# Feature Engineering-> convert raw columns into highly efficient usable ML features
#.   # PCA, LDA, bayesian analysis 
# EARLY STOPPING-> DO Not waste resources
#.     22 of you-> one letter writer
#.      TEST-> I can evaluate only 10 of you 
#.      10 of you-> Hello President -> why should I evaluate these any further?
#       instead, give these evaluation slots to others who may perform better!!!

# %%
# Data Augment (upload an image of your choice)
# !ls
# Out:
# mantisshrimp.jpg  sample_data

# %%
# !pip install Augmentor

# %%
import Augmentor
pipes = Augmentor.Pipeline('mantisshrimp')
# Pizza pipeline
# 1 person-> Call, order, baking, packing, delivery
# pipeline-> 1 person(call),...., 1(delivery)
# 100 calls, 5 pizzas at a time, 2 deliveries
# SCALED people individually!
# Out:
# Initialised with 1 image(s) found.
# Output directory set to mantisshrimp/output.

# %%
pipes.flip_left_right(0.5)
pipes.black_and_white(0.1)
pipes.random_distortion(1, 10,10, 1)
pipes.rotate(0.5, 25, 25)
pipes.skew(0.25, 0.25)
pipes.sample(5)
# Out:
# Processing <PIL.Image.Image image mode=RGB size=872x579 at 0x7FDE6EE5A550>: 100%|██████████| 5/5 [00:01<00:00,  3.37 Samples/s]

# %%
# !ls mantisshrimp/output
# Out:
# mantisshrimp_original_mantisshrimp.jpg_188ee34e-dcba-40e2-a136-9b06a5e3b792.jpg
# mantisshrimp_original_mantisshrimp.jpg_316e4eec-87e1-4019-83a6-eafad1d01b28.jpg
# mantisshrimp_original_mantisshrimp.jpg_45ba33ae-a1b3-4bbf-b352-abfe6ca25c86.jpg
# mantisshrimp_original_mantisshrimp.jpg_6c6e7614-a32a-4753-bb28-6b186adb5050.jpg
# mantisshrimp_original_mantisshrimp.jpg_a15d17d7-d006-4551-919a-03a35e32c9b8.jpg
# mantisshrimp_original_mantisshrimp.jpg_ba733c29-2f6c-4b82-adaf-08250393d3c6.jpg
# mantisshrimp_original_mantisshrimp.jpg_d8c0bdf0-0391-4e11-926c-8a557982c07d.jpg
# mantisshrimp_original_mantisshrimp.jpg_e70881fe-5029-48c7-8aaf-5aa7237b0d9d.jpg

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('mantisshrimp/output/mantisshrimp_original_mantisshrimp.jpg_45ba33ae-a1b3-4bbf-b352-abfe6ca25c86.jpg')
img = cv2.resize(img, (200,200))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FDE6DD4E668>

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('mantisshrimp/output/mantisshrimp_original_mantisshrimp.jpg_e70881fe-5029-48c7-8aaf-5aa7237b0d9d.jpg')
img = cv2.resize(img, (200,200))
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FDE6DD4E470>
